# %%
import pandas as pd


old_path = "/home/thivux/code/vinai/TTS/recipes/vctk/yourtts/SACH_NOI/metadata.txt"
cols = ['path', 'transcript', 'speaker', 'duration']
df = pd.read_csv(old_path, sep='|', names=cols)
df.head()

# %%
for speaker in df['speaker'].unique():
    print(speaker)

# %%
speakers = [
    "Trí_An",
    "Hoàn_Lê",
    "Quỳnh_Hái",
    "Phạm_Công_Luận",
    "Dan_Sullivan",
    "Joe_Vitale",
    "Thomas_Cathcart",
    "Khắc_Thiệu",
    "Kim_Liên",
    "Đạt_Phi",
    "Lê_Duy",
    "Nguyễn_Bảo_Hùng",
    "Minh_Dũng",
    "Phương_Ocean",
    "Nguyễn_Duy_Minh",
    "Tom_Buckley",
    "Phú_Thăng",
    "Trương_Anh_Quốc",
    "Hân_Phạm",
    "Dan_Heath",
    "Nguyên_Phong",
    "Park_Soon_Ae",
    "Trung_Hậu",
    "Diễm_Hân",
    "Thu_Hà", 
    "Trí_Tuệ_Nhân_Tạo",
    "Cá_Bống",
    "Duy_Ly",
    "Vũ_Trụ_Nguyên_Thủy",
    "Nguyễn_Trang",
    "Hoàng_Quân",
    "Đông_Quân",
    "Minh_Niệm",
    "Lôi_Mễ",
    "Lưu_Hà",
    "Chu_Hạo_Huy",
    "Hiền_Dũng",
    "Lộc_Trần",
    "Công_Nghĩa",
    "Quốc_Thịnh",
    "Trần_Trung_Đạo",
    "Khởi_Nguyên",
    "Huỳnh_Thu_Thảo",
    "Vân_Anh",
    "Giang_Nguyễn",
    "Độc_Thám_TV",
    "Di_Li",
    "Lisa_Trần",
    "Phượng_Đinh",
    "Hồng_Vị",
]

subset = df[df['speaker'].isin(speakers)]
subset['duration'].sum() / 3600

# %%
# Trí_An
# Hoàn_Lê
# Quỳnh_Hái
# Phạm_Công_Luận
# Dan_Sullivan
# Joe_Vitale
# Thomas_Cathcart
# Khắc_Thiệu
# Kim_Liên
# Đạt_Phi
# Lê_Duy
# Nguyễn_Bảo_Hùng
# Minh_Dũng
# Phương_Ocean
# Nguyễn_Duy_Minh
# Tom_Buckley
# Phú_Thăng
# Trương_Anh_Quốc
# Hân_Phạm
# Dan_Heath
# Nguyên_Phong
# Park_Soon_Ae
# Trung_Hậu
# Diễm_Hân
# Thu_Hà
# Trí_Tuệ_Nhân_Tạo
# Cá_Bống
# Duy_Ly
# Vũ_Trụ_Nguyên_Thủy
# Nguyễn_Trang
# Hoàng_Quân
# Đông_Quân
# Minh_Niệm
# Lôi_Mễ
# Lưu_Hà
# Chu_Hạo_Huy
# Hiền_Dũng
# Lộc_Trần
# Công_Nghĩa
# Quốc_Thịnh
# Trần_Trung_Đạo
# Khởi_Nguyên
# Huỳnh_Thu_Thảo
# Vân_Anh
# Giang_Nguyễn
# Độc_Thám_TV
# Di_Li
# Lisa_Trần
# Phượng_Đinh
# Hồng_Vị
# Lát_Radio
# Nghe_Nắng_Kể
# Mark_Scullard
# Julie_Nguyễn
# Ds_Ngọc
# Tuấn_Anh
# Tiểu_Yết
# MC_Thảo_Nguyên
# Văn_Hoàng
# Bách_Diệp
# Định_Phương
# Huy_Hồ
# Phạm_Ngọc_Đông
# Xíu
# Dương_Liễu
# Đàm_Thanh_Phượng
# Trường_Tân
# Việt_Dũng

# %%
subset.to_csv("SACH_NOI/metadata_50speakers.txt", sep='|', header=False, index=False)
